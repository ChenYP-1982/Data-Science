# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pmdarima.arima import auto_arima
from ipywidgets import interact, widget
from sklearn.metrics import mean_absolute_error
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
df=pd\
.read_csv\
("/Users/chenyenpin/Downloads/Datasets/monthly.csv", parse_dates=["Month"], index_col=["Month"])

df.head()
# Out:
#             Unnamed: 0  Price
# Month
# 2000-01-01          36   2.42
# 2000-02-01          37   2.66
# 2000-03-01          38   2.79
# 2000-04-01          39   3.04
# 2000-05-01          40   3.59

# %%
df=df.drop("Unnamed: 0", axis=1)

# %%
df.shape
# Out:
# (248, 1)

# %%
df.describe(percentiles=[.01, .1, .25, .5, .75, .99]).T
# Out:
#        count      mean      std   min      1%   10%     25%    50%     75%  \
# Price  248.0  4.486774  2.19639  1.63  1.7447  2.34  2.8775  3.905  5.8125
#
#            99%    max
# Price  12.2482  13.42

# %%
df.isna().sum()
# Out:
# Price    0
# dtype: int64

# %%
@interact(windowsize=(3,200,3))
def rolling_mean(windowsize):
    plt.figure(figsize=(18,7))
    df.rolling(windowsize).mean().plot()
    plt.show()
# Out:
# interactive(children=(IntSlider(value=99, description='windowsize', max=200, min=3, step=3), Output()), _dom_c…

# %%
plt.boxplot(df, notch=True, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc774199640>,
#   <matplotlib.lines.Line2D at 0x7fc774199b50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc77417a250>,
#   <matplotlib.lines.Line2D at 0x7fc77417aa30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc774199070>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc77417af70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc77417aa60>],
#  'means': []}

# %%
decompose=seasonal_decompose(df)

# %%
trend=decompose.trend
season=decompose.seasonal
resid=decompose.resid

# %%
plt.subplot(4,1,1)
plt.plot(df, label="Grafico")
plt.legend(loc="best")
plt.subplot(4,1,2)
plt.plot(trend, label="Tendencia")
plt.legend(loc="best")
plt.subplot(4,1,3)
plt.plot(season, label="Sasonalidade")
plt.legend(loc="best")
plt.subplot(4,1,4)
plt.plot(resid, label="aleatoriedade")
plt.legend(loc="best")
plt.tight_layout()

# %%
result=adfuller(df["Price"].dropna())
print(f"Teste ADF: {result[0]}")
print(f"Teste p-value: {result[1]}")
# Out:
# Teste ADF: -1.9199962977117597
# Teste p-value: 0.3227134775174372

# %%
result=adfuller(df["Price"].diff().dropna())
print(f"Teste ADF: {result[0]}")
print(f"Teste p-value: {result[1]}")
# Out:
# Teste ADF: -7.1467546954607775
# Teste p-value: 3.217864737854518e-10

# %%
step_wise=auto_arima(df, d=1, start_p=1, start_q=1, max_p=3,max_q=3,
                     seasonal=True, m=18, D=1, start_P=1,
                     start_Q=1, max_P=2, max_Q=2, information_criterion="aic",
                     trace=True, stepwise=False)
# Out:
#  ARIMA(0,1,0)(0,1,0)[18]             : AIC=692.399, Time=0.10 sec
#  ARIMA(0,1,0)(0,1,1)[18]             : AIC=inf, Time=0.55 sec
#  ARIMA(0,1,0)(0,1,2)[18]             : AIC=inf, Time=1.56 sec
#  ARIMA(0,1,0)(1,1,0)[18]             : AIC=640.964, Time=0.21 sec
#  ARIMA(0,1,0)(1,1,1)[18]             : AIC=inf, Time=0.81 sec
#  ARIMA(0,1,0)(1,1,2)[18]             : AIC=inf, Time=5.81 sec
#  ARIMA(0,1,0)(2,1,0)[18]             : AIC=616.125, Time=0.63 sec
#  ARIMA(0,1,0)(2,1,1)[18]             : AIC=inf, Time=1.61 sec
#  ARIMA(0,1,0)(2,1,2)[18]             : AIC=inf, Time=6.82 sec
#  ARIMA(0,1,1)(0,1,0)[18]             : AIC=693.192, Time=0.10 sec
#  ARIMA(0,1,1)(0,1,1)[18]             : AIC=inf, Time=0.85 sec
#  ARIMA(0,1,1)(0,1,2)[18]             : AIC=inf, Time=1.87 sec
#  ARIMA(0,1,1)(1,1,0)[18]             : AIC=642.796, Time=0.34 sec
#  ARIMA(0,1,1)(1,1,1)[18]             : AIC=inf, Time=1.16 sec
#  ARIMA(0,1,1)(1,1,2)[18]             : AIC=inf, Time=6.53 sec
#  ARIMA(0,1,1)(2,1,0)[18]             : AIC=618.099, Time=0.77 sec
#  ARIMA(0,1,1)(2,1,1)[18]             : AIC=inf, Time=2.58 sec
#  ARIMA(0,1,1)(2,1,2)[18]             : AIC=inf, Time=8.72 sec
#  ARIMA(0,1,2)(0,1,0)[18]             : AIC=695.191, Time=0.12 sec
#  ARIMA(0,1,2)(0,1,1)[18]             : AIC=inf, Time=1.25 sec
#  ARIMA(0,1,2)(0,1,2)[18]             : AIC=inf, Time=3.47 sec
#  ARIMA(0,1,2)(1,1,0)[18]             : AIC=644.645, Time=0.33 sec
#  ARIMA(0,1,2)(1,1,1)[18]             : AIC=inf, Time=1.20 sec
#  ARIMA(0,1,2)(1,1,2)[18]             : AIC=inf, Time=6.77 sec
#  ARIMA(0,1,2)(2,1,0)[18]             : AIC=620.068, Time=0.97 sec
#  ARIMA(0,1,2)(2,1,1)[18]             : AIC=inf, Time=2.78 sec
#  ARIMA(0,1,3)(0,1,0)[18]             : AIC=696.049, Time=0.14 sec
#  ARIMA(0,1,3)(0,1,1)[18]             : AIC=inf, Time=1.51 sec
#  ARIMA(0,1,3)(0,1,2)[18]             : AIC=inf, Time=2.84 sec
#  ARIMA(0,1,3)(1,1,0)[18]             : AIC=646.420, Time=0.43 sec
#  ARIMA(0,1,3)(1,1,1)[18]             : AIC=inf, Time=1.74 sec
#  ARIMA(0,1,3)(2,1,0)[18]             : AIC=622.056, Time=0.94 sec
#  ARIMA(1,1,0)(0,1,0)[18]             : AIC=693.215, Time=0.08 sec
#  ARIMA(1,1,0)(0,1,1)[18]             : AIC=inf, Time=0.80 sec
#  ARIMA(1,1,0)(0,1,2)[18]             : AIC=inf, Time=1.69 sec
#  ARIMA(1,1,0)(1,1,0)[18]             : AIC=642.805, Time=0.36 sec
#  ARIMA(1,1,0)(1,1,1)[18]             : AIC=inf, Time=0.99 sec
#  ARIMA(1,1,0)(1,1,2)[18]             : AIC=inf, Time=4.33 sec
#  ARIMA(1,1,0)(2,1,0)[18]             : AIC=618.099, Time=0.86 sec
#  ARIMA(1,1,0)(2,1,1)[18]             : AIC=inf, Time=2.10 sec
#  ARIMA(1,1,0)(2,1,2)[18]             : AIC=inf, Time=6.34 sec
#  ARIMA(1,1,1)(0,1,0)[18]             : AIC=695.192, Time=0.13 sec
#  ARIMA(1,1,1)(0,1,1)[18]             : AIC=inf, Time=1.21 sec
#  ARIMA(1,1,1)(0,1,2)[18]             : AIC=inf, Time=3.64 sec
#  ARIMA(1,1,1)(1,1,0)[18]             : AIC=inf, Time=2.09 sec
#  ARIMA(1,1,1)(1,1,1)[18]             : AIC=inf, Time=1.96 sec
#  ARIMA(1,1,1)(1,1,2)[18]             : AIC=inf, Time=6.48 sec
#  ARIMA(1,1,1)(2,1,0)[18]             : AIC=620.090, Time=1.55 sec
#  ARIMA(1,1,1)(2,1,1)[18]             : AIC=inf, Time=6.35 sec
#  ARIMA(1,1,2)(0,1,0)[18]             : AIC=697.088, Time=0.18 sec
#  ARIMA(1,1,2)(0,1,1)[18]             : AIC=inf, Time=1.21 sec
#  ARIMA(1,1,2)(0,1,2)[18]             : AIC=inf, Time=2.57 sec
#  ARIMA(1,1,2)(1,1,0)[18]             : AIC=646.596, Time=0.90 sec
#  ARIMA(1,1,2)(1,1,1)[18]             : AIC=inf, Time=1.40 sec
#  ARIMA(1,1,2)(2,1,0)[18]             : AIC=615.832, Time=4.39 sec
#  ARIMA(1,1,3)(0,1,0)[18]             : AIC=inf, Time=0.59 sec
#  ARIMA(1,1,3)(0,1,1)[18]             : AIC=inf, Time=3.70 sec
#  ARIMA(1,1,3)(1,1,0)[18]             : AIC=647.220, Time=1.41 sec
#  ARIMA(2,1,0)(0,1,0)[18]             : AIC=695.142, Time=0.13 sec
#  ARIMA(2,1,0)(0,1,1)[18]             : AIC=inf, Time=1.07 sec
#  ARIMA(2,1,0)(0,1,2)[18]             : AIC=inf, Time=2.12 sec
#  ARIMA(2,1,0)(1,1,0)[18]             : AIC=644.622, Time=0.36 sec
#  ARIMA(2,1,0)(1,1,1)[18]             : AIC=inf, Time=1.21 sec
#  ARIMA(2,1,0)(1,1,2)[18]             : AIC=inf, Time=6.02 sec
#  ARIMA(2,1,0)(2,1,0)[18]             : AIC=620.067, Time=0.88 sec
#  ARIMA(2,1,0)(2,1,1)[18]             : AIC=inf, Time=3.25 sec
#  ARIMA(2,1,1)(0,1,0)[18]             : AIC=696.947, Time=0.29 sec
#  ARIMA(2,1,1)(0,1,1)[18]             : AIC=inf, Time=2.06 sec
#  ARIMA(2,1,1)(0,1,2)[18]             : AIC=inf, Time=3.21 sec
#  ARIMA(2,1,1)(1,1,0)[18]             : AIC=646.549, Time=0.66 sec
#  ARIMA(2,1,1)(1,1,1)[18]             : AIC=inf, Time=2.87 sec
#  ARIMA(2,1,1)(2,1,0)[18]             : AIC=622.067, Time=1.00 sec
#  ARIMA(2,1,2)(0,1,0)[18]             : AIC=inf, Time=0.93 sec
#  ARIMA(2,1,2)(0,1,1)[18]             : AIC=inf, Time=2.90 sec
#  ARIMA(2,1,2)(1,1,0)[18]             : AIC=inf, Time=2.13 sec
#  ARIMA(2,1,3)(0,1,0)[18]             : AIC=inf, Time=1.16 sec
#  ARIMA(3,1,0)(0,1,0)[18]             : AIC=695.903, Time=0.12 sec
#  ARIMA(3,1,0)(0,1,1)[18]             : AIC=inf, Time=1.23 sec
#  ARIMA(3,1,0)(0,1,2)[18]             : AIC=inf, Time=2.64 sec
#  ARIMA(3,1,0)(1,1,0)[18]             : AIC=646.307, Time=0.42 sec
#  ARIMA(3,1,0)(1,1,1)[18]             : AIC=inf, Time=2.03 sec
#  ARIMA(3,1,0)(2,1,0)[18]             : AIC=622.065, Time=1.22 sec
#  ARIMA(3,1,1)(0,1,0)[18]             : AIC=697.873, Time=0.22 sec
#  ARIMA(3,1,1)(0,1,1)[18]             : AIC=inf, Time=2.07 sec
#  ARIMA(3,1,1)(1,1,0)[18]             : AIC=648.305, Time=0.75 sec
#  ARIMA(3,1,2)(0,1,0)[18]             : AIC=694.912, Time=0.74 sec
#
# Best model:  ARIMA(1,1,2)(2,1,0)[18]
# Total fit time: 167.715 seconds

# %%
print(step_wise.aic())
# Out:
# 641.6850380338

# %%
df.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-02-01', '2000-03-01', '2000-04-01',
#                '2000-05-01', '2000-06-01', '2000-07-01', '2000-08-01',
#                '2000-09-01', '2000-10-01',
#                ...
#                '2019-11-01', '2019-12-01', '2020-01-01', '2020-02-01',
#                '2020-03-01', '2020-04-01', '2020-05-01', '2020-06-01',
#                '2020-07-01', '2020-08-01'],
#               dtype='datetime64[ns]', name='Month', length=248, freq=None)

# %%
train=df['2010-01-01':"2018-12-01"]
test=df["2019-01-01":]

# %%
len(test)
# Out:
# 20

# %%
step_wise.fit(train)
# Out:
# ARIMA(order=(1, 1, 2), scoring_args={}, seasonal_order=(2, 1, 0, 18),
#       suppress_warnings=True, with_intercept=False)

# %%
predict=step_wise.predict(n_periods=30)

# %%
predict
# Out:
# 2019-01-01    3.974826
# 2019-02-01    3.799640
# 2019-03-01    3.827565
# 2019-04-01    3.741208
# 2019-05-01    3.936400
# 2019-06-01    3.733611
# 2019-07-01    4.144277
# 2019-08-01    3.500824
# 2019-09-01    3.534301
# 2019-10-01    3.509035
# 2019-11-01    3.517392
# 2019-12-01    3.756810
# 2020-01-01    3.659208
# 2020-02-01    3.619905
# 2020-03-01    3.610356
# 2020-04-01    3.680818
# 2020-05-01    4.009708
# 2020-06-01    3.901703
# 2020-07-01    3.985381
# 2020-08-01    3.788486
# 2020-09-01    3.730980
# 2020-10-01    3.733034
# 2020-11-01    3.852737
# 2020-12-01    3.939688
# 2021-01-01    4.402594
# 2021-02-01    3.873934
# 2021-03-01    3.950146
# 2021-04-01    3.953465
# 2021-05-01    3.815925
# 2021-06-01    4.307067
# Freq: MS, dtype: float64

# %%
tabela=pd.DataFrame()
tabela["test"]=test
tabela["predict"]=predict
sns.lineplot(tabela)
plt.xticks(rotation=60, ha="right")
# Out:
# (array([17897., 17956., 18017., 18078., 18140., 18201., 18262., 18322.,
#         18383., 18444.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
tabela
# Out:
#             test   predict
# Month
# 2019-01-01  3.11  3.974826
# 2019-02-01  2.69  3.799640
# 2019-03-01  2.95  3.827565
# 2019-04-01  2.65  3.741208
# 2019-05-01  2.64  3.936400
# 2019-06-01  2.40  3.733611
# 2019-07-01  2.37  4.144277
# 2019-08-01  2.22  3.500824
# 2019-09-01  2.56  3.534301
# 2019-10-01  2.33  3.509035
# 2019-11-01  2.65  3.517392
# 2019-12-01  2.22  3.756810
# 2020-01-01  2.02  3.659208
# 2020-02-01  1.91  3.619905
# 2020-03-01  1.79  3.610356
# 2020-04-01  1.74  3.680818
# 2020-05-01  1.75  4.009708
# 2020-06-01  1.63  3.901703
# 2020-07-01  1.77  3.985381
# 2020-08-01  2.30  3.788486

# %%
modelo=SARIMAX(df,order=(0,1,0), seasonal_order=(2,1,0,18 ))
resultado_sarimax=modelo.fit()
# Out:
# /Users/chenyenpin/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/chenyenpin/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.23012D+00    |proj g|=  7.37361D-03
#
# At iterate    5    f=  1.23009D+00    |proj g|=  1.88045D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   2.899D-06   1.230D+00
#   F =   1.2300905545477245
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %%
resultado_sarimax.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Price   No. Observations:                  248
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 18)   Log Likelihood                -305.062
# Date:                            Sun, 11 Jun 2023   AIC                            616.125
# Time:                                    09:40:27   BIC                            626.426
# Sample:                                01-01-2000   HQIC                           620.281
#                                      - 08-01-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L18      -0.6286      0.057    -10.940      0.000      -0.741      -0.516
# ar.S.L36      -0.3389      0.048     -7.103      0.000      -0.432      -0.245
# sigma2         0.8087      0.045     17.818      0.000       0.720       0.898
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):               177.62
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.12   Skew:                            -0.70
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
predicao=resultado_sarimax.get_prediction(start=-12)
predicao_media=predicao.predicted_mean
int_conf=predicao.conf_int()

# %%
limite_baixo_pred=int_conf.iloc[:,0]
limite_alto_pred=int_conf.iloc[:,1]
display(limite_baixo_pred[1], limite_alto_pred[1],predicao_media[1], df)
# Out:
# 0.7608615287440026
# 4.285957146708915
# 2.523409337726459
#             Price
# Month
# 2000-01-01   2.42
# 2000-02-01   2.66
# 2000-03-01   2.79
# 2000-04-01   3.04
# 2000-05-01   3.59
# ...           ...
# 2020-04-01   1.74
# 2020-05-01   1.75
# 2020-06-01   1.63
# 2020-07-01   1.77
# 2020-08-01   2.30
#
# [248 rows x 1 columns]

# %%
date_pred=np.asarray(predicao_media.index)
date=np.asarray(df.index)
date
# Out:
# array(['2000-01-01T00:00:00.000000000', '2000-02-01T00:00:00.000000000',
#        '2000-03-01T00:00:00.000000000', '2000-04-01T00:00:00.000000000',
#        '2000-05-01T00:00:00.000000000', '2000-06-01T00:00:00.000000000',
#        '2000-07-01T00:00:00.000000000', '2000-08-01T00:00:00.000000000',
#        '2000-09-01T00:00:00.000000000', '2000-10-01T00:00:00.000000000',
#        '2000-11-01T00:00:00.000000000', '2000-12-01T00:00:00.000000000',
#        '2001-01-01T00:00:00.000000000', '2001-02-01T00:00:00.000000000',
#        '2001-03-01T00:00:00.000000000', '2001-04-01T00:00:00.000000000',
#        '2001-05-01T00:00:00.000000000', '2001-06-01T00:00:00.000000000',
#        '2001-07-01T00:00:00.000000000', '2001-08-01T00:00:00.000000000',
#        '2001-09-01T00:00:00.000000000', '2001-10-01T00:00:00.000000000',
#        '2001-11-01T00:00:00.000000000', '2001-12-01T00:00:00.000000000',
#        '2002-01-01T00:00:00.000000000', '2002-02-01T00:00:00.000000000',
#        '2002-03-01T00:00:00.000000000', '2002-04-01T00:00:00.000000000',
#        '2002-05-01T00:00:00.000000000', '2002-06-01T00:00:00.000000000',
01T00:00:00.000000000',
#        '2017-01-01T00:00:00.000000000', '2017-02-01T00:00:00.000000000',
#        '2017-03-01T00:00:00.000000000', '2017-04-01T00:00:00.000000000',
#        '2017-05-01T00:00:00.000000000', '2017-06-01T00:00:00.000000000',
#        '2017-07-01T00:00:00.000000000', '2017-08-01T00:00:00.000000000',
#        '2017-09-01T00:00:00.000000000', '2017-10-01T00:00:00.000000000',
#        '2017-11-01T00:00:00.000000000', '2017-12-01T00:00:00.000000000',
#        '2018-01-01T00:00:00.000000000', '2018-02-01T00:00:00.000000000',
#        '2018-03-01T00:00:00.000000000', '2018-04-01T00:00:00.000000000',
#        '2018-05-01T00:00:00.000000000', '2018-06-01T00:00:00.000000000',
#        '2018-07-01T00:00:00.000000000', '2018-08-01T00:00:00.000000000',
#        '2018-09-01T00:00:00.000000000', '2018-10-01T00:00:00.000000000',
#        '2018-11-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2019-01-01T00:00:00.000000000', '2019-02-01T00:00:00.000000000',
#        '2019-03-01T00:00:00.000000000', '2019-04-01T00:00:00.000000000',
#        '2019-05-01T00:00:00.000000000', '2019-06-01T00:00:00.000000000',
#        '2019-07-01T00:00:00.000000000', '2019-08-01T00:00:00.000000000',
#        '2019-09-01T00:00:00.000000000', '2019-10-01T00:00:00.000000000',
#        '2019-11-01T00:00:00.000000000', '2019-12-01T00:00:00.000000000',
#        '2020-01-01T00:00:00.000000000', '2020-02-01T00:00:00.000000000',
#        '2020-03-01T00:00:00.000000000', '2020-04-01T00:00:00.000000000',
#        '2020-05-01T00:00:00.000000000', '2020-06-01T00:00:00.000000000',
#        '2020-07-01T00:00:00.000000000', '2020-08-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
mae=mean_absolute_error(df[-12:], predicao_media.values)
mae
# Out:
# 0.27710480002191124

# %%
plt.figure(figsize=(20,10))
plt.plot(date, df, label="Original", color="grey")
plt.plot(date_pred, predicao_media.values, label="Predicao", color="blue")

# %%
forecast=resultado_sarimax.get_forecast(steps=18)
forecast_mean=forecast.predicted_mean
forecast_mean
# Out:
# 2020-09-01    2.331643
# 2020-10-01    2.255629
# 2020-11-01    2.289583
# 2020-12-01    2.372425
# 2021-01-01    2.743454
# 2021-02-01    2.340046
# 2021-03-01    2.529722
# 2021-04-01    2.472784
# 2021-05-01    2.445926
# 2021-06-01    2.687886
# 2021-07-01    2.474774
# 2021-08-01    2.319104
# 2021-09-01    2.296292
# 2021-10-01    2.433398
# 2021-11-01    2.688751
# 2021-12-01    2.572091
# 2022-01-01    2.354621
# 2022-02-01    2.402661
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
forecast_conf=forecast.conf_int()
forecast_conf
limite_abaixo_fore=forecast_conf.iloc[:,0]
limite_acima_fore=forecast_conf.iloc[:,1]
forecast_mean[1], limite_abaixo_fore[1], limite_acima_fore[1]
# Out:
# (2.255629429502432, -0.23698958627901368, 4.748248445283878)

# %%
date_fore=np.asarray(forecast_mean.index)

# %%
plt.figure(figsize=(20,10))
plt.plot(date, df, label="Original", color="grey")
plt.plot(date_pred, predicao_media.values, label="Predicao", color="blue")
plt.plot(date_fore, forecast_mean.values, label="Previsao", color="red")
